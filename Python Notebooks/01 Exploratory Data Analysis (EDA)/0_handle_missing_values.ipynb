# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in d:\my files\projects\_venv_\ml\lib\site-packages (from -r requirements.txt (line 1)) (2.3.4)
# Requirement already satisfied: pandas in d:\my files\projects\_venv_\ml\lib\site-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: scikit-learn in d:\my files\projects\_venv_\ml\lib\site-packages (from -r requirements.txt (line 3)) (1.7.2)
# Requirement already satisfied: openai in d:\my files\projects\_venv_\ml\lib\site-packages (from -r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: groq in d:\my files\projects\_venv_\ml\lib\site-packages (from -r requirements.txt (line 5)) (0.32.0)
# Requirement already satisfied: seaborn in d:\my files\projects\_venv_\ml\lib\site-packages (from -r requirements.txt (line 6)) (0.13.2)
# Requirement already satisfied: dotenv in d:\my files\projects\_venv_\ml\lib\site-packages (from -r requirements.txt (line 7)) (0.9.9)
# Requirement already satisfied: matplotlib in d:\my files\projects\_venv_\ml\lib\site-packages (from -r requirements.txt (line 8)) (3.10.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\my files\projects\_venv_\ml\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\my files\projects\_venv_\ml\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\my files\projects\_venv_\ml\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in d:\my files\projects\_venv_\ml\lib\site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in d:\my files\projects\_venv_\ml\lib\site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\my files\projects\_venv_\ml\lib\site-packages (from scikit-learn->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\my files\projects\_venv_\ml\lib\site-packages (from openai->-r requirements.txt (line 4)) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\my files\projects\_venv_\ml\lib\site-packages (from openai->-r requirements.txt (line 4)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\my files\projects\_venv_\ml\lib\site-packages (from openai->-r requirements.txt (line 4)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in d:\my files\projects\_venv_\ml\lib\site-packages (from openai->-r requirements.txt (line 4)) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\my files\projects\_venv_\ml\lib\site-packages (from openai->-r requirements.txt (line 4)) (2.12.3)
# Requirement already satisfied: sniffio in d:\my files\projects\_venv_\ml\lib\site-packages (from openai->-r requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: tqdm>4 in d:\my files\projects\_venv_\ml\lib\site-packages (from openai->-r requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in d:\my files\projects\_venv_\ml\lib\site-packages (from openai->-r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: idna>=2.8 in d:\my files\projects\_venv_\ml\lib\site-packages (from anyio<5,>=3.5.0->openai->-r requirements.txt (line 4)) (3.11)
# Requirement already satisfied: certifi in d:\my files\projects\_venv_\ml\lib\site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 4)) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in d:\my files\projects\_venv_\ml\lib\site-packages (from httpx<1,>=0.23.0->openai->-r requirements.txt (line 4)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\my files\projects\_venv_\ml\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r requirements.txt (line 4)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\my files\projects\_venv_\ml\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\my files\projects\_venv_\ml\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 4)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\my files\projects\_venv_\ml\lib\site-packages (from pydantic<3,>=1.9.0->openai->-r requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: python-dotenv in d:\my files\projects\_venv_\ml\lib\site-packages (from dotenv->-r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\my files\projects\_venv_\ml\lib\site-packages (from matplotlib->-r requirements.txt (line 8)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\my files\projects\_venv_\ml\lib\site-packages (from matplotlib->-r requirements.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\my files\projects\_venv_\ml\lib\site-packages (from matplotlib->-r requirements.txt (line 8)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\my files\projects\_venv_\ml\lib\site-packages (from matplotlib->-r requirements.txt (line 8)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\my files\projects\_venv_\ml\lib\site-packages (from matplotlib->-r requirements.txt (line 8)) (25.0)
# Requirement already satisfied: pillow>=8 in d:\my files\projects\_venv_\ml\lib\site-packages (from matplotlib->-r requirements.txt (line 8)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in d:\my files\projects\_venv_\ml\lib\site-packages (from matplotlib->-r requirements.txt (line 8)) (3.2.5)
# Requirement already satisfied: six>=1.5 in d:\my files\projects\_venv_\ml\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: colorama in d:\my files\projects\_venv_\ml\lib\site-packages (from tqdm>4->openai->-r requirements.txt (line 4)) (0.4.6)

# %% [markdown]
# ### 1. Import Dependencies

# %%
import os
from enum import Enum
import seaborn as sns
from pydantic import BaseModel
from dotenv import load_dotenv
import numpy as np # alias
import openai, groq
import pandas as pd # alias

load_dotenv()
# Out:
# True

# %%
os.getcwd()
# Out:
# 'd:\\MY FILES\\Projects\\bank-customer-churn-prediction-eda-scripting\\Python Notebooks\\01 Exploratory Data Analysis (EDA)'

# %% [markdown]
# ### 2. Basic Information

# %%
df = pd.read_csv('data/raw/ChurnModelling.csv')
df.head(15)
# Out:
#     RowNumber  CustomerId Firstname  Lastname  CreditScore Geography  Gender  \
# 0           1    15634602     Grace  Williams          619    France  Female
# 1           2    15647311     David     Jones          608     Spain  Female
# 2           3    15619304      Hank  Williams          502    France  Female
# 3           4    15701354       Eva    Taylor          699    France  Female
# 4           5    15737888     Grace    Miller          850     Spain  Female
# 5           6    15574012      Jack     Smith          645     Spain    Male
# 6           7    15592531     Carol    Wilson          822    France    Male
# 7           8    15656148     Grace    Wilson          376   Germany  Female
# 8           9    15792365      Hank     Jones          501    France    Male
# 9          10    15592389       Eva    Wilson          684    France    Male
# 10         11    15767821     David    Taylor          528    France    Male
# 11         12    15737173      Hank    Garcia          497     Spain    Male
# 12         13    15632264      Hank     Jones          476    France  Female
# 13         14    15691483     Carol  Williams          549    France  Female
# 14         15    15600882     Frank     Davis          635     Spain  Female
#
#      Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0   42.0       2       0.00              1          1               1
# 1   41.0       1   83807.86              1          0               1
# 2   42.0       8  159660.80              3          1               0
# 3    NaN       1       0.00              2          0               0
# 4   43.0       2  125510.82              1          1               1
# 5   44.0       8  113755.78              2          1               0
# 6   50.0       7       0.00              2          1               1
# 7   29.0       4  115046.74              4          1               0
# 8   44.0       4  142051.07              2          0               1
# 9   27.0       2  134603.88              1          1               1
# 10  31.0       6  102016.72              2          0               0
# 11  24.0       3       0.00              2          1               0
# 12  34.0      10       0.00              2          1               0
# 13  25.0       5       0.00              2          0               0
# 14  35.0       7       0.00              2          1               1
#
#     EstimatedSalary  Exited
# 0         101348.88       1
# 1         112542.58       0
# 2         113931.57       1
# 3          93826.63       0
# 4          79084.10       0
# 5         149756.71       1
# 6          10062.80       0
# 7         119346.88       1
# 8          74940.50       0
# 9          71725.73       0
# 10         80181.12       0
# 11         76390.01       0
# 12         26260.98       0
# 13        190857.79       0
# 14         65951.65       0

# %% [markdown]
# NaN = Not a Number

# %%
# get null values
df.isnull().sum()
# Out:
# RowNumber            0
# CustomerId           0
# Firstname            7
# Lastname             6
# CreditScore          0
# Geography            0
# Gender             108
# Age                600
# Tenure               0
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Exited               0
# dtype: int64

# %% [markdown]
# ### 3. Handle Missing Values

# %% [markdown]
# #### 3.1 Deletion

# %% [markdown]
# **axis = 1** -> check each column and drop if atleast 1 null value consists of <br/>
# **axis = 0** -> check each row and drop if atleast 1 null value consists of

# %%
df_cp = df.copy()
df_cp = df_cp.dropna(axis=0) 
df_cp
# Out:
#       RowNumber  CustomerId Firstname  Lastname  CreditScore Geography  \
# 0             1    15634602     Grace  Williams          619    France
# 1             2    15647311     David     Jones          608     Spain
# 2             3    15619304      Hank  Williams          502    France
# 4             5    15737888     Grace    Miller          850     Spain
# 5             6    15574012      Jack     Smith          645     Spain
# ...         ...         ...       ...       ...          ...       ...
# 9995       9996    15606229     Grace    Garcia          771    France
# 9996       9997    15569892      Jack    Garcia          516    France
# 9997       9998    15584532     Carol   Johnson          709    France
# 9998       9999    15682355      Jack    Garcia          772   Germany
# 9999      10000    15628319       Eva    Garcia          792    France
#
#       Gender   Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0     Female  42.0       2       0.00              1          1
# 1     Female  41.0       1   83807.86              1          0
# 2     Female  42.0       8  159660.80              3          1
# 4     Female  43.0       2  125510.82              1          1
# 5       Male  44.0       8  113755.78              2          1
# ...      ...   ...     ...        ...            ...        ...
# 9995    Male  39.0       5       0.00              2          1
# 9996    Male  35.0      10   57369.61              1          1
# 9997  Female  36.0       7       0.00              1          0
# 9998    Male  42.0       3   75075.31              2          1
# 9999  Female  28.0       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited
# 0                  1        101348.88       1
# 1                  1        112542.58       0
# 2                  0        113931.57       1
# 4                  1         79084.10       0
# 5                  0        149756.71       1
# ...              ...              ...     ...
# 9995               0         96270.64       0
# 9996               1        101699.77       0
# 9997               1         42085.58       1
# 9998               0         92888.52       1
# 9999               0         38190.78       0
#
# [9337 rows x 15 columns]

# %%
10000 - 9337
# Out:
# 663

# %%
df_cp = df.copy()
df_cp = df_cp.dropna(axis=1) 
df_cp
# Out:
#       RowNumber  CustomerId  CreditScore Geography  Tenure    Balance  \
# 0             1    15634602          619    France       2       0.00
# 1             2    15647311          608     Spain       1   83807.86
# 2             3    15619304          502    France       8  159660.80
# 3             4    15701354          699    France       1       0.00
# 4             5    15737888          850     Spain       2  125510.82
# ...         ...         ...          ...       ...     ...        ...
# 9995       9996    15606229          771    France       5       0.00
# 9996       9997    15569892          516    France      10   57369.61
# 9997       9998    15584532          709    France       7       0.00
# 9998       9999    15682355          772   Germany       3   75075.31
# 9999      10000    15628319          792    France       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0                 1          1               1        101348.88       1
# 1                 1          0               1        112542.58       0
# 2                 3          1               0        113931.57       1
# 3                 2          0               0         93826.63       0
# 4                 1          1               1         79084.10       0
# ...             ...        ...             ...              ...     ...
# 9995              2          1               0         96270.64       0
# 9996              1          1               1        101699.77       0
# 9997              1          0               1         42085.58       1
# 9998              2          1               0         92888.52       1
# 9999              1          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %% [markdown]
# #### 3.2 Imputation

# %% [markdown]
# The possible ways to do this are:
#
# - Filling the missing data with the mean or median value if it’s a numerical variable.
# - Filling the missing data with mode if it’s a categorical value.
# - Filling the numerical value with 0 or -999, or some other number that will not occur in the data. This can be done so that the machine can recognize that the data is not real or is different.
# - Filling the categorical value with a new type for the missing values.

# %% [markdown]
# ##### 3.2.1 Age

# %%
mean = df['Age'].mean()
median = df['Age'].median()
mean = round(mean, 2)

print(f"Mean | Age : {mean}")
print(f"Median | Age : {median}")
# Out:
# Mean | Age : 38.91
# Median | Age : 37.0

# %%
sns.histplot(df['Age'], bins=30)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df_impute = df.copy()

# %%
df_impute.loc[:, 'Age'] = df_impute['Age'].fillna(mean)
df_impute.head()
# Out:
#    RowNumber  CustomerId Firstname  Lastname  CreditScore Geography  Gender  \
# 0          1    15634602     Grace  Williams          619    France  Female
# 1          2    15647311     David     Jones          608     Spain  Female
# 2          3    15619304      Hank  Williams          502    France  Female
# 3          4    15701354       Eva    Taylor          699    France  Female
# 4          5    15737888     Grace    Miller          850     Spain  Female
#
#      Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0  42.00       2       0.00              1          1               1
# 1  41.00       1   83807.86              1          0               1
# 2  42.00       8  159660.80              3          1               0
# 3  38.91       1       0.00              2          0               0
# 4  43.00       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# get null values
df_impute.isnull().sum()
# Out:
# RowNumber            0
# CustomerId           0
# Firstname            7
# Lastname             6
# CreditScore          0
# Geography            0
# Gender             108
# Age                  0
# Tenure               0
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Exited               0
# dtype: int64

# %% [markdown]
# ##### 3.2.2 Gender

# %%
class Gender(str, Enum):
    MALE = "Male"
    FEMALE = "Female"

class GenderPrediction(BaseModel):
    firstname: str 
    lastname: str
    pred_gender: Gender

def predict_gender(
                firstname: str,
                lastname: str
                ):
    prompt = f"""
                What is the most likely gender (Male or Female) for someone with the first name '{firstname}'
                and last name '{lastname}' ?

                Your response only consists of one word: Male or Female
                """
    
    response = groq.Groq().chat.completions.create(
                                                    model="llama-3.3-70b-versatile",
                                                    messages=[{
                                                                "role": "user",
                                                                "content": prompt
                                                            }]
                                                    )
    predicted_gender = response.choices[0].message.content.strip()
    prediction = GenderPrediction(
                                firstname=firstname ,
                                lastname=lastname,
                                pred_gender=predicted_gender
                                )
    return prediction.pred_gender

# %%
predict_gender("Isuru", "Alagiyawanna")
# Out:
# <Gender.MALE: 'Male'>

# %%
missing_gender_index = df_impute['Gender'].isnull()
for idx in df_impute[missing_gender_index].index:
    first_name = df_impute.loc[idx, 'Firstname']
    last_name = df_impute.loc[idx, 'Lastname']
    gender = predict_gender(first_name, last_name)
    
    if gender:
        df_impute.loc[idx, 'Gender'] = gender
        print(f"{first_name} {last_name} : {gender}")
    else:
        print(f"{first_name} {last_name} : No Gender Detected")
# Out:
# Eva Wilson : Gender.FEMALE
# Ivy Johnson : Gender.FEMALE
# David Taylor : Gender.MALE
# Frank Davis : Gender.MALE
# Jack Wilson : Gender.MALE
# David Miller : Gender.MALE
# Eva Taylor : Gender.FEMALE
# Grace Johnson : Gender.FEMALE
# Hank Miller : Gender.MALE
# Frank Williams : Gender.MALE
# Alice Davis : Gender.FEMALE
# Alice Brown : Gender.FEMALE
# Alice Garcia : Gender.FEMALE
# Bob Jones : Gender.MALE
# Jack Davis : Gender.MALE
# Grace Williams : Gender.FEMALE
# Ivy Jones : Gender.FEMALE
# David Smith : Gender.MALE
# David Miller : Gender.MALE
# Eva Williams : Gender.FEMALE
# Frank Garcia : Gender.MALE
# Alice Wilson : Gender.FEMALE
# Carol Jones : Gender.FEMALE
# Hank Davis : Gender.MALE
# Ivy Williams : Gender.FEMALE
# Hank Smith : Gender.MALE
# Ivy Jones : Gender.FEMALE
# Alice Brown : Gender.FEMALE
# Eva Taylor : Gender.FEMALE
# Carol Williams : Gender.FEMALE
# Jack Williams : Gender.MALE
# Ivy Brown : Gender.FEMALE
# David Brown : Gender.MALE
# Bob Smith : Gender.MALE
# Frank Wilson : Gender.MALE
# Bob Williams : Gender.MALE
# Ivy Johnson : Gender.FEMALE
# Jack Taylor : Gender.MALE
# David Davis : Gender.MALE
# David Garcia : Gender.MALE
# Eva Brown : Gender.FEMALE
# Frank Wilson : Gender.MALE
# Jack Davis : Gender.MALE
# Eva Miller : Gender.FEMALE
# Grace Williams : Gender.FEMALE
# Bob Jones : Gender.MALE
# David Taylor : Gender.MALE
# Frank Smith : Gender.MALE
# Ivy Jones : Gender.FEMALE
# David Williams : Gender.MALE
# Grace Jones : Gender.FEMALE
# Grace Miller : Gender.FEMALE
# Bob Taylor : Gender.MALE
# Grace Miller : Gender.FEMALE
# Bob Taylor : Gender.MALE
# Hank Jones : Gender.MALE
# Hank Wilson : Gender.MALE
# Grace Smith : Gender.FEMALE
# Bob Johnson : Gender.MALE
# Hank Brown : Gender.MALE
# Carol Jones : Gender.FEMALE
# Hank Williams : Gender.MALE
# Hank Miller : Gender.MALE
# Frank Davis : Gender.MALE
# Ivy Wilson : Gender.FEMALE
# Hank Jones : Gender.MALE
# Bob Jones : Gender.MALE
# Frank Brown : Gender.MALE
# Frank Smith : Gender.MALE
# Bob Taylor : Gender.MALE
# Alice Johnson : Gender.FEMALE
# Ivy Wilson : Gender.FEMALE
# Grace Brown : Gender.FEMALE
# Eva Davis : Gender.FEMALE
# Eva Wilson : Gender.FEMALE
# Frank Miller : Gender.MALE
# David Miller : Gender.MALE
# Carol Brown : Gender.FEMALE
# Eva Miller : Gender.FEMALE
# Alice Garcia : Gender.FEMALE
# Carol Davis : Gender.FEMALE
# Frank Smith : Gender.MALE
# Ivy Miller : Gender.FEMALE
# Bob Garcia : Gender.MALE
# Alice Garcia : Gender.FEMALE
# Frank Smith : Gender.MALE
# Grace Johnson : Gender.FEMALE
# Eva Garcia : Gender.FEMALE
# Alice Jones : Gender.FEMALE
# David Wilson : Gender.MALE
# Ivy Garcia : Gender.FEMALE
# Frank Wilson : Gender.MALE
# Frank Wilson : Gender.MALE
# Bob Williams : Gender.MALE
# Ivy Johnson : Gender.FEMALE
# David Brown : Gender.MALE
# Ivy Miller : Gender.FEMALE
# Carol Smith : Gender.FEMALE
# David Williams : Gender.MALE
# Hank Williams : Gender.MALE
# David Brown : Gender.MALE
# Carol Garcia : Gender.FEMALE
# Hank Miller : Gender.MALE
# Grace Wilson : Gender.FEMALE
# Hank Johnson : Gender.MALE
# Grace Jones : Gender.FEMALE
# Alice Davis : Gender.FEMALE
# Jack Brown : Gender.MALE

# %%
# get null values
df_impute.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Firstname          7
# Lastname           6
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df_impute = df_impute.drop(
                            columns=[
                                    'RowNumber',
                                    'CustomerId',
                                    'Firstname',
                                    'Lastname'
                                    ]
                            )
df_impute.head()
# Out:
#    CreditScore Geography  Gender    Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female  42.00       2       0.00              1
# 1          608     Spain  Female  41.00       1   83807.86              1
# 2          502    France  Female  42.00       8  159660.80              3
# 3          699    France  Female  38.91       1       0.00              2
# 4          850     Spain  Female  43.00       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# get null values
df_impute.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df_impute.to_csv(
                'data/processed/ChurnModelling_Missing_Values_Handled.csv', 
                index=False
                )
